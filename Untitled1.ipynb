# %% [markdown]
# <a href="https://colab.research.google.com/github/ibra-00/DNA-Analyzer/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-80c94df7-fd45-4c5b-9ebf-e55fa8607be1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-80c94df7-fd45-4c5b-9ebf-e55fa8607be1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('placement.csv')
df.head()
# Out:
#    id  cgpa   iq  placement
# 0   1  3.85  120          1
# 1   2  2.95   95          0
# 2   3  3.60  115          1
# 3   4  2.70   85          0

# %%
df.shape
# Out:
# (4, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         4 non-null      int64
#  1   cgpa       4 non-null      float64
#  2   iq         4 non-null      int64
#  3   placement  4 non-null      int64
# dtypes: float64(1), int64(3)
# memory usage: 260.0 bytes

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa   iq  placement
# 0  3.85  120          1
# 1  2.95   95          0
# 2  3.60  115          1
# 3  2.70   85          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'], df['iq'], c=df['placement'])
plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.title('Placement Dataset')
plt.show()

# %%
X= df.iloc[:,0:2]
y= df.iloc[:,-1]

# %%
X
# Out:
#    cgpa   iq
# 0  3.85  120
# 1  2.95   95
# 2  3.60  115
# 3  2.70   85

# %%
y
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# Name: placement, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#    cgpa   iq
# 2  3.60  115
# 1  2.95   95
# 3  2.70   85

# %%
y_train
# Out:
# 2    1
# 1    0
# 3    0
# Name: placement, dtype: int64

# %%
X_test
# Out:
#    cgpa   iq
# 0  3.85  120

# %%
y_test
# Out:
# 0    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.3620618 ,  1.33630621],
#        [-0.35149982, -0.26726124],
#        [-1.01056198, -1.06904497]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[2.02112397, 1.73719807]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf =LogisticRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 0    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
